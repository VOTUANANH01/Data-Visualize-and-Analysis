# %% [markdown]
# # <h1> Import dataset

# %%
# link dataset: https://data.cityofnewyork.us/Transportation/2020-Green-Taxi-Trip-Data/pkmi-4kfn
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/DS105/Do_An/"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # <h1>2. Tiền xử lí </h1>

# %% [markdown]
# ## <h1> 2.2.Bổ sung bộ dữ liệu </h1>

# %%
#loading dataset
df_step3=pd.read_csv(path+"dataset/df_step2.csv",index_col=False)

# %% [markdown]
# ### <h3> 2.2.1 Merge bộ dữ liệu </h3>

# %%
# link: https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page
lc_detail=pd.read_csv(path+"dataset/taxi+_zone_lookup.csv")
#thay thế các giá trị NaN = Unknown
lc_detail=lc_detail.fillna("Unknown")

# %%
lc_detail
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV      Unknown
# 264         265        Unknown                  Unknown      Unknown
#
# [265 rows x 4 columns]

# %%
def merging(l_df,r_df,*l_key,r_key):
  temp=pd.DataFrame({})
  for a,key in enumerate(l_key):
    #tại l_key đầu tiên thì
    if a == 0:
      #tạo tên gọi thuộc tính mới
      str = key[0:2] +'_'
      #tiến hành merge hai bộ dữ liệu
      df_merge=pd.merge(left=l_df,right=r_df,left_on=key,right_on=r_key)
      #loại bỏ cột thừa
      df_merge=df_merge.drop(r_key,axis=1)
      #lấy ra những tên cột thuộc tính được thêm mới
      name=df_merge.columns.intersection(r_df.columns)
      #gán tên mới cho các cột thuộc tính được thêm
      for i,n in enumerate(name):
        new = str + name[i]
        df_merge.rename(columns={n:new},inplace=True)
      #trả dataframe về 1 biến tạm
      temp=df_merge
    else:
      # tới l_key tiếp theo thực hiện đệ quy lại
      return merging(temp,r_df,key,r_key=r_key)
  #trả về dataframe
  return temp

# %%
#sau khi merge sẽ sắp xếp lại thứ tự theo cột cuối được chọn
df_merge=merging(df_step3,lc_detail,'PULocationID','DOLocationID',r_key='LocationID')
df_merge
# Out:
#          VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 0               2  12/18/2019 03:52:30 PM  12/18/2019 03:54:39 PM
# 1               2  01/01/2020 12:43:33 AM  01/01/2020 12:44:02 AM
# 2               1  01/01/2020 12:11:35 AM  01/01/2020 12:39:51 AM
# 3               2  01/01/2020 01:06:18 AM  01/01/2020 01:06:20 AM
# 4               2  01/01/2020 12:54:05 AM  01/01/2020 12:54:07 AM
# ...           ...                     ...                     ...
# 1728768         2  08/12/2020 11:04:00 AM  08/12/2020 12:02:00 PM
# 1728769         2  06/23/2020 04:40:00 AM  06/23/2020 05:12:00 AM
# 1728770         2  05/11/2020 09:44:24 AM  05/11/2020 10:28:44 AM
# 1728771         2  09/11/2020 06:11:43 AM  09/11/2020 06:12:57 AM
# 1728772         2  09/11/2020 06:17:19 AM  09/11/2020 06:18:20 AM
#
#          store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                         0           1           264           264
# 1                         0           5           264           264
# 2                         0           1           264           264
# 3                         0           5           264           264
# 4                         0           5           264           264
# ...                     ...         ...           ...           ...
# 1728768                   0           1           197            99
# 1728769                   0           1           169            99
# 1728770                   0           1            38            99
# 1728771                   0           1            99            99
# 1728772                   0           1            99            99
#
#          passenger_count  trip_distance  fare_amount  ...  total_amount  \
# 0                      5           0.00         3.50  ...          4.81
# 1                      1           0.28         5.55  ...         15.55
# 2                      1           6.80        26.50  ...         27.80
# 3                      1           0.00        45.00  ...         54.36
# 4                      1           0.00        55.00  ...         66.00
# ...                  ...            ...          ...  ...           ...
# 1728768                1          33.82        94.21  ...        109.50
# 1728769                1          34.25        96.70  ...        120.50
# 1728770                1          31.57        83.50  ...         99.29
# 1728771                1           0.00         3.00  ...          3.80
# 1728772                1           0.00         2.50  ...          3.30
#
#          payment_type  trip_type  congestion_surcharge     PU_Borough  \
# 0                   1          1                   0.0        Unknown
# 1                   1          2                   0.0        Unknown
# 2                   1          1                   0.0        Unknown
# 3                   1          2                   0.0        Unknown
# 4                   1          2                   0.0        Unknown
# ...               ...        ...                   ...            ...
# 1728768             1          1                   0.0         Queens
# 1728769             1          1                   0.0          Bronx
# 1728770             1          1                   0.0         Queens
# 1728771             2          1                   0.0  Staten Island
# 1728772             2          1                   0.0  Staten Island
#
#                  PU_Zone  PU_service_zone     DO_Borough          DO_Zone  \
# 0                     NV          Unknown        Unknown               NV
# 1                     NV          Unknown        Unknown               NV
# 2                     NV          Unknown        Unknown               NV
# 3                     NV          Unknown        Unknown               NV
# 4                     NV          Unknown        Unknown               NV
# ...                  ...              ...            ...              ...
# 1728768    Richmond Hill        Boro Zone  Staten Island  Freshkills Park
# 1728769       Mount Hope        Boro Zone  Staten Island  Freshkills Park
# 1728770  Cambria Heights        Boro Zone  Staten Island  Freshkills Park
# 1728771  Freshkills Park        Boro Zone  Staten Island  Freshkills Park
# 1728772  Freshkills Park        Boro Zone  Staten Island  Freshkills Park
#
#         DO_service_zone
# 0               Unknown
# 1               Unknown
# 2               Unknown
# 3               Unknown
# 4               Unknown
# ...                 ...
# 1728768       Boro Zone
# 1728769       Boro Zone
# 1728770       Boro Zone
# 1728771       Boro Zone
# 1728772       Boro Zone
#
# [1728773 rows x 25 columns]

# %% [markdown]
# ### <h3> 2.2.2 Triết xuất data từ hai cột lpep_pickup_datetime và	lpep_dropoff_datetime để có những cột thuộc tính mới </h3>

# %%
import datetime as dt

# %%
# chuyển datatype của lpep_pickup_datetime và	lpep_dropoff_datetime	 dạng date_time
df_merge['lpep_pickup_datetime']= pd.to_datetime(df_merge['lpep_pickup_datetime'])
df_merge ['lpep_dropoff_datetime']= pd.to_datetime(df_merge['lpep_dropoff_datetime'])

# %%
#quan sát cột 'lpep_pickup_datetime' sau khi thay đổi kiểu dữ liệu
df_merge['lpep_pickup_datetime']
# Out:
# 0         2019-12-18 15:52:30
# 1         2020-01-01 00:43:33
# 2         2020-01-01 00:11:35
# 3         2020-01-01 01:06:18
# 4         2020-01-01 00:54:05
#                   ...
# 1728768   2020-08-12 11:04:00
# 1728769   2020-06-23 04:40:00
# 1728770   2020-05-11 09:44:24
# 1728771   2020-09-11 06:11:43
# 1728772   2020-09-11 06:17:19
# Name: lpep_pickup_datetime, Length: 1728773, dtype: datetime64[ns]

# %%
#quan sát cột 'lpep_dropoff_datetime' sau khi thay đổi kiểu dữ liệu
df_merge['lpep_dropoff_datetime']
# Out:
# 0         2019-12-18 15:54:39
# 1         2020-01-01 00:44:02
# 2         2020-01-01 00:39:51
# 3         2020-01-01 01:06:20
# 4         2020-01-01 00:54:07
#                   ...
# 1728768   2020-08-12 12:02:00
# 1728769   2020-06-23 05:12:00
# 1728770   2020-05-11 10:28:44
# 1728771   2020-09-11 06:12:57
# 1728772   2020-09-11 06:18:20
# Name: lpep_dropoff_datetime, Length: 1728773, dtype: datetime64[ns]

# %%
#tạo biến thời gian hoàn thành chuyến đi
time_diff=df_merge['lpep_dropoff_datetime']-df_merge['lpep_pickup_datetime']

# %%
#đưa về đơn vị là phút
for i, time in enumerate(time_diff):
  time_diff[i]=time_diff[i].seconds/60

# %%
df_time=df_merge.copy()

# %%
#thêm cột dữ liệu mới
df_time['trip_duration']=time_diff

# %%
#rút trích data từ các 'lpep_dropoff_datetime' và 'lpep_dropoff_datetime' để lấy ra month (tháng), thứ (được encode:0 ->6 tương đương với bảy ngày), hour(giờ)
for j in ["pickup","dropoff"]:
 df_time[j+"_month"] = df_time['lpep_'+j+'_datetime'].dt.month
 df_time[j+"_weekday"] = df_time['lpep_'+j+'_datetime'].dt.weekday
 df_time[j+"_hour"] = df_time['lpep_'+j+'_datetime'].dt.hour

# %%
#tạo cột thuộc tính khoảng giờ theo 3 khoảng: [16,20) - rush, [20,6) - overnight, [6,16) - other, được chia cách tính tiền phụ phí của taxi
#https://www1.nyc.gov/site/tlc/passengers/taxi-fare.page
def bin_hour(t):
  if t in range(16,20):
    return "rush"
  if t in range(6,16):
    return "others"
  else:
    return "overnight"

# %%
df_time["pickup_bin_hours"]=df_time['pickup_hour'].apply(bin_hour)
df_time["dropoff_bin_hours"]=df_time['dropoff_hour'].apply(bin_hour)

# %%
df_time.head(10)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime  store_and_fwd_flag  \
# 0         2  2019-12-18 15:52:30   2019-12-18 15:54:39                   0
# 1         2  2020-01-01 00:43:33   2020-01-01 00:44:02                   0
# 2         1  2020-01-01 00:11:35   2020-01-01 00:39:51                   0
# 3         2  2020-01-01 01:06:18   2020-01-01 01:06:20                   0
# 4         2  2020-01-01 00:54:05   2020-01-01 00:54:07                   0
# 5         2  2020-01-01 01:11:41   2020-01-01 01:11:43                   0
# 6         2  2020-01-01 01:22:30   2020-01-01 01:22:31                   0
# 7         2  2020-01-01 01:11:43   2020-01-01 01:11:43                   0
# 8         2  2020-01-01 02:02:42   2020-01-01 02:02:44                   0
# 9         2  2020-01-01 02:32:23   2020-01-01 02:32:25                   0
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           264           264                5           0.00
# 1           5           264           264                1           0.28
# 2           1           264           264                1           6.80
# 3           5           264           264                1           0.00
# 4           5           264           264                1           0.00
# 5           5           264           264                1           0.00
# 6           1           264           264                1           0.00
# 7           1           264           264                1           0.00
# 8           5           264           264                1           0.00
# 9           5           264           264                1           0.10
#
#    fare_amount  ...  DO_service_zone  trip_duration  pickup_month  \
# 0         3.50  ...          Unknown           2.15            12
# 1         5.55  ...          Unknown       0.483333             1
# 2        26.50  ...          Unknown      28.266667             1
# 3        45.00  ...          Unknown       0.033333             1
# 4        55.00  ...          Unknown       0.033333             1
# 5        10.00  ...          Unknown       0.033333             1
# 6         2.50  ...          Unknown       0.016667             1
# 7         2.50  ...          Unknown            0.0             1
# 8        30.00  ...          Unknown       0.033333             1
# 9        50.00  ...          Unknown       0.033333             1
#
#    pickup_weekday  pickup_hour  dropoff_month  dropoff_weekday  dropoff_hour  \
# 0               2           15             12                2            15
# 1               2            0              1                2             0
# 2               2            0              1                2             0
# 3               2            1              1                2             1
# 4               2            0              1                2             0
# 5               2            1              1                2             1
# 6               2            1              1                2             1
# 7               2            1              1                2             1
# 8               2            2              1                2             2
# 9               2            2              1                2             2
#
#    pickup_bin_hours dropoff_bin_hours
# 0            others            others
# 1         overnight         overnight
# 2         overnight         overnight
# 3         overnight         overnight
# 4         overnight         overnight
# 5         overnight         overnight
# 6         overnight         overnight
# 7         overnight         overnight
# 8         overnight         overnight
# 9         overnight         overnight
#
# [10 rows x 34 columns]

# %%
df_time.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag                int64
# RatecodeID                        int64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                   int64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge             int64
# total_amount                    float64
# payment_type                      int64
# trip_type                         int64
# congestion_surcharge            float64
# PU_Borough                       object
# PU_Zone                          object
# PU_service_zone                  object
# DO_Borough                       object
# DO_Zone                          object
# DO_service_zone                  object
# trip_duration                    object
# pickup_month                      int64
# pickup_weekday                    int64
# pickup_hour                       int64
# dropoff_month                     int64
# dropoff_weekday                   int64
# dropoff_hour                      int64
# pickup_bin_hours                 object
# dropoff_bin_hours                object
# dtype: object

# %%
#số cột thuộc tính sau khi mở rộng dataset
df_time.shape[1]
# Out:
# 34

# %%
#lưu lại dataset
df_time.to_csv(path+"dataset/finall_data.csv",index=False)
