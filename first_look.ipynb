# %% [markdown]
# # <h1> Import dataset

# %%
# link dataset: https://data.cityofnewyork.us/Transportation/2020-Green-Taxi-Trip-Data/pkmi-4kfn
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/DS105/Do_An/"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(path+"dataset/2020_Green_Taxi_Trip_Data.csv")
# Out:
# <ipython-input-7-2bf463c0b7df>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path+"dataset/2020_Green_Taxi_Trip_Data.csv")

# %% [markdown]
# #1. Các thông tin cơ bản của dataset

# %%
#số lượng sample và số thuộc tính
df.shape
# Out:
# (1734051, 20)

# %%
#10 sample đầu
df.head(10)
# Out:
#    VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 0       2.0  12/18/2019 03:52:30 PM  12/18/2019 03:54:39 PM
# 1       2.0  01/01/2020 12:45:58 AM  01/01/2020 12:56:39 AM
# 2       2.0  01/01/2020 12:41:38 AM  01/01/2020 12:52:49 AM
# 3       1.0  01/01/2020 12:52:46 AM  01/01/2020 01:14:21 AM
# 4       1.0  01/01/2020 12:19:57 AM  01/01/2020 12:30:56 AM
# 5       1.0  01/01/2020 12:52:33 AM  01/01/2020 01:09:54 AM
# 6       2.0  01/01/2020 12:10:18 AM  01/01/2020 12:22:16 AM
# 7       2.0  01/01/2020 01:03:14 AM  01/01/2020 01:29:45 AM
# 8       2.0  01/01/2020 12:04:11 AM  01/01/2020 12:09:48 AM
# 9       2.0  01/01/2020 12:25:52 AM  01/01/2020 12:32:16 AM
#
#   store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  passenger_count  \
# 0                  N         1.0           264           264              5.0
# 1                  N         5.0            66            65              2.0
# 2                  N         1.0           181           228              1.0
# 3                  N         1.0           129           263              2.0
# 4                  N         1.0           210           150              1.0
# 5                  N         1.0            35            39              1.0
# 6                  N         1.0            25            61              1.0
# 7                  N         1.0           225            89              1.0
# 8                  N         1.0           129           129              1.0
# 9                  N         1.0           129            83              1.0
#
#    trip_distance  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           0.00          3.5   0.50      0.5        0.01           0.0
# 1           1.28         20.0   0.00      0.0        4.06           0.0
# 2           2.47         10.5   0.50      0.5        3.54           0.0
# 3           6.30         21.0   3.25      0.5        0.00           0.0
# 4           2.30         10.0   0.50      0.5        0.00           0.0
# 5           3.00         13.5   0.50      0.5        0.00           0.0
# 6           2.77         11.0   0.50      0.5        0.00           0.0
# 7           4.98         20.5   0.50      0.5        0.00           0.0
# 8           0.71          5.5   0.50      0.5        0.00           0.0
# 9           0.80          5.5   0.50      0.5        0.00           0.0
#
#    ehail_fee  improvement_surcharge  total_amount  payment_type  trip_type  \
# 0        NaN                    0.3          4.81           1.0        1.0
# 1        NaN                    0.3         24.36           1.0        2.0
# 2        NaN                    0.3         15.34           1.0        1.0
# 3        NaN                    0.3         25.05           2.0        1.0
# 4        NaN                    0.3         11.30           1.0        1.0
# 5        NaN                    0.3         14.80           1.0        1.0
# 6        NaN                    0.3         12.30           2.0        1.0
# 7        NaN                    0.3         21.80           2.0        1.0
# 8        NaN                    0.3          6.80           2.0        1.0
# 9        NaN                    0.3          6.80           2.0        1.0
#
#    congestion_surcharge
# 0                  0.00
# 1                  0.00
# 2                  0.00
# 3                  2.75
# 4                  0.00
# 5                  0.00
# 6                  0.00
# 7                  0.00
# 8                  0.00
# 9                  0.00

# %%
#10 sample cuối
df.tail(10)
# Out:
#          VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 1734041       NaN  12/31/2020 10:03:00 PM  12/31/2020 10:23:00 PM
# 1734042       NaN  12/31/2020 10:59:00 PM  12/31/2020 11:11:00 PM
# 1734043       NaN  12/31/2020 10:17:00 PM  12/31/2020 10:43:00 PM
# 1734044       NaN  12/31/2020 10:15:00 PM  12/31/2020 10:56:00 PM
# 1734045       NaN  12/31/2020 11:49:00 PM  01/01/2021 12:14:00 AM
# 1734046       NaN  12/31/2020 11:02:00 PM  12/31/2020 11:16:00 PM
# 1734047       NaN  12/31/2020 11:39:00 PM  12/31/2020 11:54:00 PM
# 1734048       NaN  12/31/2020 11:09:00 PM  12/31/2020 11:33:00 PM
# 1734049       NaN  12/31/2020 11:01:00 PM  12/31/2020 11:12:00 PM
# 1734050       NaN  12/31/2020 11:12:00 PM  12/31/2020 11:37:00 PM
#
#         store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 1734041                NaN         NaN           136            41
# 1734042                NaN         NaN           126           213
# 1734043                NaN         NaN           159            81
# 1734044                NaN         NaN            61            18
# 1734045                NaN         NaN           130            37
# 1734046                NaN         NaN           174           168
# 1734047                NaN         NaN           256           225
# 1734048                NaN         NaN           146            10
# 1734049                NaN         NaN           196            28
# 1734050                NaN         NaN           215            35
#
#          passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 1734041              NaN           5.44        32.24    0.0      0.0
# 1734042              NaN           2.48        18.95    0.0      0.0
# 1734043              NaN           7.85        24.58    0.0      0.0
# 1734044              NaN          20.80        52.26    0.0      0.0
# 1734045              NaN           8.44        37.88    0.0      0.0
# 1734046              NaN           7.04        20.33    0.0      0.0
# 1734047              NaN           2.79        13.17    0.0      0.0
# 1734048              NaN          12.41        45.12    0.0      0.0
# 1734049              NaN           4.46        13.96    0.0      0.0
# 1734050              NaN          10.34        39.95    0.0      0.0
#
#          tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 1734041        2.75          0.00        NaN                    0.3
# 1734042        2.75          0.00        NaN                    0.3
# 1734043        0.00          0.00        NaN                    0.3
# 1734044        2.75          6.12        NaN                    0.3
# 1734045        2.75          0.00        NaN                    0.3
# 1734046        0.00          0.00        NaN                    0.3
# 1734047        0.00          0.00        NaN                    0.3
# 1734048        2.75          0.00        NaN                    0.3
# 1734049        3.13          0.00        NaN                    0.3
# 1734050        2.75          0.00        NaN                    0.3
#
#          total_amount  payment_type  trip_type  congestion_surcharge
# 1734041         35.29           NaN        NaN                   NaN
# 1734042         22.00           NaN        NaN                   NaN
# 1734043         24.88           NaN        NaN                   NaN
# 1734044         61.43           NaN        NaN                   NaN
# 1734045         40.93           NaN        NaN                   NaN
# 1734046         20.63           NaN        NaN                   NaN
# 1734047         13.47           NaN        NaN                   NaN
# 1734048         48.17           NaN        NaN                   NaN
# 1734049         17.39           NaN        NaN                   NaN
# 1734050         43.00           NaN        NaN                   NaN

# %%
#8 sample bất kỳ
df.sample(n=8)
# Out:
#          VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 1731693       NaN  12/30/2020 08:44:00 AM  12/30/2020 09:02:00 AM
# 437311        NaN  01/28/2020 05:30:00 PM  01/28/2020 06:02:00 PM
# 780486        NaN  02/06/2020 10:41:00 AM  02/06/2020 11:00:00 AM
# 236814        2.0  01/23/2020 04:40:22 PM  01/23/2020 04:50:07 PM
# 1239878       1.0  07/11/2020 11:18:30 AM  07/11/2020 11:33:39 AM
# 454652        2.0  02/01/2020 05:44:57 PM  02/01/2020 05:59:08 PM
# 972691        2.0  03/13/2020 02:01:25 PM  03/13/2020 02:09:50 PM
# 195150        2.0  01/19/2020 01:06:23 PM  01/19/2020 01:23:07 PM
#
#         store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 1731693                NaN         NaN           260           138
# 437311                 NaN         NaN            25            89
# 780486                 NaN         NaN           155            35
# 236814                   N         1.0           130           205
# 1239878                  N         1.0           244           100
# 454652                   N         1.0           244           238
# 972691                   N         1.0            74            75
# 195150                   N         1.0           196           129
#
#          passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 1731693              NaN           4.28        11.35   0.00      0.0
# 437311               NaN           3.97        21.64   2.75      0.0
# 780486               NaN           3.89        29.02   0.00      0.0
# 236814               1.0           2.32         9.50   1.00      0.5
# 1239878              1.0           7.20        21.50   2.75      0.5
# 454652               1.0           4.68        16.50   0.00      0.5
# 972691               2.0           1.16         7.50   0.00      0.5
# 195150               2.0           1.71        11.50   0.00      0.5
#
#          tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 1731693        1.29           0.0        NaN                    0.3
# 437311         0.00           0.0        NaN                    0.3
# 780486         0.00           0.0        NaN                    0.3
# 236814         2.26           0.0        NaN                    0.3
# 1239878        4.00           0.0        NaN                    0.3
# 454652         4.01           0.0        NaN                    0.3
# 972691         0.00           0.0        NaN                    0.3
# 195150         2.46           0.0        NaN                    0.3
#
#          total_amount  payment_type  trip_type  congestion_surcharge
# 1731693         12.94           NaN        NaN                   NaN
# 437311          24.69           NaN        NaN                   NaN
# 780486          29.32           NaN        NaN                   NaN
# 236814          13.56           1.0        1.0                  0.00
# 1239878         29.05           1.0        1.0                  2.75
# 454652          24.06           1.0        1.0                  2.75
# 972691           8.30           2.0        1.0                  0.00
# 195150          14.76           1.0        1.0                  0.00

# %%
#mô tả thống kê
df.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  1.205959e+06  1.205959e+06  1.734051e+06  1.734051e+06
# mean   1.829832e+00  1.118096e+00  1.082483e+02  1.287863e+02
# std    3.757807e-01  7.140995e-01  7.080140e+01  7.642577e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.000000e+00  1.000000e+00  5.200000e+01  6.300000e+01
# 50%    2.000000e+00  1.000000e+00  8.100000e+01  1.270000e+02
# 75%    2.000000e+00  1.000000e+00  1.660000e+02  1.930000e+02
# max    2.000000e+00  9.900000e+01  2.650000e+02  2.650000e+02
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     1.205959e+06   1.734051e+06  1.734051e+06  1.734051e+06
# mean      1.291327e+00   1.729224e+01  1.698479e+01  5.418312e-01
# std       9.547199e-01   1.198165e+03  1.380515e+01  9.482827e-01
# min       0.000000e+00  -3.369000e+01 -2.100000e+02 -4.500000e+00
# 25%       1.000000e+00   1.130000e+00  7.500000e+00  0.000000e+00
# 50%       1.000000e+00   2.210000e+00  1.250000e+01  0.000000e+00
# 75%       1.000000e+00   4.870000e+00  2.211000e+01  1.000000e+00
# max       9.000000e+00   2.056541e+05  8.030000e+02  1.674000e+01
#
#             mta_tax    tip_amount  tolls_amount  ehail_fee  \
# count  1.734051e+06  1.734051e+06  1.734051e+06        0.0
# mean   3.480491e-01  1.263318e+00  4.129915e-01        NaN
# std    2.325786e-01  2.228201e+00  1.659563e+00        NaN
# min   -5.000000e-01 -1.056000e+01 -6.120000e+00        NaN
# 25%    0.000000e+00  0.000000e+00  0.000000e+00        NaN
# 50%    5.000000e-01  0.000000e+00  0.000000e+00        NaN
# 75%    5.000000e-01  2.750000e+00  0.000000e+00        NaN
# max    3.550000e+00  6.412000e+02  9.612000e+01        NaN
#
#        improvement_surcharge  total_amount  payment_type     trip_type  \
# count           1.734051e+06  1.734051e+06  1.205959e+06  1.205954e+06
# mean            2.932526e-01  2.016313e+01  1.459929e+00  1.026295e+00
# std             4.914765e-02  1.527308e+01  5.219627e-01  1.600123e-01
# min            -3.000000e-01 -2.103000e+02  1.000000e+00  1.000000e+00
# 25%             3.000000e-01  9.360000e+00  1.000000e+00  1.000000e+00
# 50%             3.000000e-01  1.570000e+01  1.000000e+00  1.000000e+00
# 75%             3.000000e-01  2.600000e+01  2.000000e+00  1.000000e+00
# max             3.000000e-01  8.038000e+02  5.000000e+00  2.000000e+00
#
#        congestion_surcharge
# count          1.205959e+06
# mean           4.842113e-01
# std            1.047322e+00
# min           -2.750000e+00
# 25%            0.000000e+00
# 50%            0.000000e+00
# 75%            0.000000e+00
# max            2.750000e+00

# %%
#kiểu dữ liệu của từng fearture
df.dtypes
# Out:
# VendorID                 float64
# lpep_pickup_datetime      object
# lpep_dropoff_datetime     object
# store_and_fwd_flag        object
# RatecodeID               float64
# PULocationID               int64
# DOLocationID               int64
# passenger_count          float64
# trip_distance            float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# ehail_fee                float64
# improvement_surcharge    float64
# total_amount             float64
# payment_type             float64
# trip_type                float64
# congestion_surcharge     float64
# dtype: object

# %%
#Kiểm tra có thuộc tính bị khuyết
df.isnull().any()
# Out:
# VendorID                  True
# lpep_pickup_datetime     False
# lpep_dropoff_datetime    False
# store_and_fwd_flag        True
# RatecodeID                True
# PULocationID             False
# DOLocationID             False
# passenger_count           True
# trip_distance            False
# fare_amount              False
# extra                    False
# mta_tax                  False
# tip_amount               False
# tolls_amount             False
# ehail_fee                 True
# improvement_surcharge    False
# total_amount             False
# payment_type              True
# trip_type                 True
# congestion_surcharge      True
# dtype: bool

# %%
#số lượng index bị khuyết dữ liệu theo từng thuộc tính
df.isnull().sum()/df.shape[0]
# Out:
# VendorID                 0.304542
# lpep_pickup_datetime     0.000000
# lpep_dropoff_datetime    0.000000
# store_and_fwd_flag       0.304542
# RatecodeID               0.304542
# PULocationID             0.000000
# DOLocationID             0.000000
# passenger_count          0.304542
# trip_distance            0.000000
# fare_amount              0.000000
# extra                    0.000000
# mta_tax                  0.000000
# tip_amount               0.000000
# tolls_amount             0.000000
# ehail_fee                1.000000
# improvement_surcharge    0.000000
# total_amount             0.000000
# payment_type             0.304542
# trip_type                0.304545
# congestion_surcharge     0.304542
# dtype: float64

# %%
#tạo DataFamre df_missing với tỉ lệ khuyết dữ liệu
df_missing=df.isna().melt(value_name="missing")
df_missing=(df_missing.groupby(['variable'])['missing']
                     .value_counts(normalize=True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index())

# %%
df_missing
# Out:
#                  variable  missing  percentage
# 0            DOLocationID    False  100.000000
# 1            PULocationID    False  100.000000
# 2              RatecodeID    False   69.545763
# 3              RatecodeID     True   30.454237
# 4                VendorID    False   69.545763
# 5                VendorID     True   30.454237
# 6    congestion_surcharge    False   69.545763
# 7    congestion_surcharge     True   30.454237
# 8               ehail_fee     True  100.000000
# 9                   extra    False  100.000000
# 10            fare_amount    False  100.000000
# 11  improvement_surcharge    False  100.000000
# 12  lpep_dropoff_datetime    False  100.000000
# 13   lpep_pickup_datetime    False  100.000000
# 14                mta_tax    False  100.000000
# 15        passenger_count    False   69.545763
# 16        passenger_count     True   30.454237
# 17           payment_type    False   69.545763
# 18           payment_type     True   30.454237
# 19     store_and_fwd_flag    False   69.545763
# 20     store_and_fwd_flag     True   30.454237
# 21             tip_amount    False  100.000000
# 22           tolls_amount    False  100.000000
# 23           total_amount    False  100.000000
# 24          trip_distance    False  100.000000
# 25              trip_type    False   69.545475
# 26              trip_type     True   30.454525

# %%
#trực quan dữ liệu bị khuyết
sns.set(rc={'figure.figsize':(15,12)})
plot=sns.barplot(
    data=df_missing,
    x="variable",
    y='percentage',
    hue="missing",
)
fig=plot.get_figure()
plt.xticks(rotation=45)
plt.title("visualizing_missing_data")
plt.show()
fig.savefig(path+"picture/visualizing_missing_data.png", dpi=100)

# %% [markdown]
# Các nhận xét sau khi kiểm tra các thuộc tính có khuyết dữ liệu hay không: <br>
# - ehail_fee: số lượng index khuyết bằng với số lượng datapoint của dataset => tiến hành loại bỏ <br>
#
# - Các thuộc tính bị khuyết còn lại bao gồm: VendorID, store_and_fwd_flag, RatecodeID, passenger_count, payment_type, trip_type,congestion_surcharge hầu như có số lượng dữ liệu khyết là như nhau và chênh lệch không quá 5 đơn vị <br>
